# %%
import os
import json
import random
from collections import defaultdict

# **Folder tempat data FHIR yang sudah diproses**
data_folder = "synthea/output/fhir"
output_folder = "synthea/output/processed/"
os.makedirs(output_folder, exist_ok=True)

# **Mengumpulkan semua file dalam folder**
json_files = [f for f in os.listdir(data_folder) if f.endswith(".json")]

# **Dictionary untuk menyimpan resource berdasarkan tipe**
resources = defaultdict(list)

# **Membaca Semua File dan Memisahkan Resource**
for file in json_files:
    file_path = os.path.join(data_folder, file)
    print(f"📂 Membaca file: {file}")

    with open(file_path, "r", encoding="utf-8") as f:
        try:
            data = json.load(f)

            # Jika JSON adalah FHIR Bundle, cek `entry`
            if "entry" in data:
                for entry in data["entry"]:
                    resource = entry["resource"]
                    resource_type = resource["resourceType"]
                    resources[resource_type].append(resource)
            else:
                # Jika JSON langsung berupa satu resource
                resource_type = data["resourceType"]
                resources[resource_type].append(data)

        except json.JSONDecodeError as e:
            print(f"⚠️ Error membaca JSON di {file}: {e}")

# **Mendapatkan Daftar Pasien**
patients = resources["Patient"]
patient_ids = [p["id"] for p in patients]
patient_data = {p["id"]: p for p in patients}  # Simpan detail pasien

print(f"\n✅ Jumlah pasien ditemukan: {len(patients)}")
# Out:
# 📂 Membaca file: Adell482_Runolfsdottir785_7da148be-b73e-73e3-ed5c-67d7c712a253.json
# 📂 Membaca file: Alease857_Jerde200_d4f1d88b-aecc-493e-2977-44a72e0de2d9.json
# 📂 Membaca file: Alesha810_Sanford861_9f7675c1-1f29-10ac-92e5-8aaf367f05c3.json
# 📂 Membaca file: Alfred550_Ruecker817_839e461d-9a4d-a110-1fe9-97bd16378bfd.json
# 📂 Membaca file: Allene83_Cathryn51_Kerluke267_7e101445-eafd-cd17-0e6b-57f85baa3f44.json
# 📂 Membaca file: Alvaro283_Robel940_c498075d-c7cc-69ba-23c3-0e6a6c188592.json
# 📂 Membaca file: Angelo118_Halvorson124_3ada63c8-2ff1-1032-9ed5-39b5fba54c89.json
# 📂 Membaca file: Anitra287_Elena945_Doyle959_06671679-d2c8-8426-da09-7017cc0bda53.json
# 📂 Membaca file: Berna338_Paulita78_Bode78_4f370d5a-e3c8-369d-d70e-1f57ff23406a.json
# 📂 Membaca file: Bev675_Bins636_876d955b-0c84-3d32-cba7-f342a8432b47.json
# 📂 Membaca file: Brett333_Rutherford999_423b2ac4-4424-4faa-743c-cf41352c3845.json
# 📂 Membaca file: Burma963_Terry864_86f20cc9-62f7-e23e-c66b-a8acc5819976.json
# 📂 Membaca file: Caitlin552_Gislason620_a7a96e5c-cead-584b-ea1b-8ae082dab219.json
# 📂 Membaca file: Cary869_Eichmann909_198ceaf5-0d10-c644-b559-5cce84cd7a59.json
# 📂 Membaca file: Casey401_Schowalter414_67ed8fab-19a2-40c5-e56c-3dfdab2c9805.json
# 📂 Membaca file: Cesar434_Oberbrunner298_8a9451f2-3fe4-a23a-18fd-c285095cfeb6.json
# 📂 Membaca file: Charlsie105_Kovacek682_b4b40272-8e5e-1cc9-0bf6-ea931252b740.json
# 📂 Membaca file: Stephani232_Gricelda41_Hickle134_b243a40d-bab8-9284-a929-e5f11e729d5a.json
# 📂 Membaca file: Tanika746_Dorine689_Gorczany269_f5f6a690-af00-7c0f-c5c0-7bae4c3401ad.json
# 📂 Membaca file: Tasha327_Jinny850_Crist667_be222f9e-05e3-7c64-349b-02949d6222c7.json
# 📂 Membaca file: Ute382_Cassi819_Barton704_3a644dcd-672c-9579-cdeb-65ce6783da97.json
# 📂 Membaca file: Vernita491_Riva522_Rath779_f875dfc8-362f-4e0b-7af5-8e0aa600ec49.json
# 📂 Membaca file: Winford225_Grimes165_209f54b3-95fe-5295-9dce-558ddc02e0c3.json
#
# ✅ Jumlah pasien ditemukan: 108

# %%
# **Probabilitas penyakit keturunan berdasarkan data epidemiologi**
disease_probabilities = {
    "Diabetes": 0.125,
    "Hypertension": 0.35,
    "Cancer": 0.075,
    "Heart Disease": 0.225,
    "Alzheimer": 0.03,
    "Asthma": 0.10
}

# **Fungsi untuk Membuat RelatedPerson**
def create_related_person(patient_id, related_id, relation_code, relation_display):
    related_patient = patient_data[related_id]
    
    return {
        "resourceType": "RelatedPerson",
        "id": f"urn:uuid:{related_id}",
        "patient": {"reference": f"Patient/{patient_id}"},
        "relationship": [{
            "coding": [{
                "system": "http://terminology.hl7.org/CodeSystem/v3-RoleCode",
                "code": relation_code,
                "display": relation_display
            }],
            "text": relation_display
        }],
        "name": related_patient.get("name", [{"use": "official", "family": "Unknown"}]),
        "gender": related_patient.get("gender", "unknown"),
        "birthDate": related_patient.get("birthDate", "unknown")
    }

# **Fungsi untuk Membuat FamilyMemberHistory**
def create_family_member_history(patient_id, related_id, relation_code, relation_display):
    inherited_conditions = []
    
    for disease, probability in disease_probabilities.items():
        if random.random() <= probability:
            inherited_conditions.append(disease)
    
    if not inherited_conditions:
        return None, None

    family_history = {
        "resourceType": "FamilyMemberHistory",
        "id": f"family-{related_id}-",
        "patient": {"reference": f"Patient/{patient_id}"},
        "relationship": {
            "coding": [{
                "system": "http://terminology.hl7.org/CodeSystem/v3-RoleCode",
                "code": relation_code,
                "display": relation_display
            }]
        },
        "condition": [{
            "code": {
                "coding": [{
                    "system": "http://snomed.info/sct",
                    "code": "22298006",
                    "display": disease
                }],
                "text": disease
            }
        } for disease in inherited_conditions]
    }

    return family_history, inherited_conditions

# **Fungsi untuk Membuat Condition untuk RelatedPerson**
def create_condition_for_related_person(related_id, disease):
    return {
        "resourceType": "Condition",
        "id": f"condition-related-{related_id}-{disease.lower().replace(' ', '-')}",
        "subject": {"reference": f"urn:uuid:{related_id}"},
        "code": {
            "coding": [{
                "system": "http://snomed.info/sct",
                "code": "22298006",
                "display": disease
            }],
            "text": disease
        }
    }

# %%
# **Menambahkan `FamilyMemberHistory`, `RelatedPerson`, dan `Condition` ke dataset**
used_relationships = set()

for patient in patients:
    patient_id = patient["id"]
    
    possible_relations = [p for p in patient_ids if p != patient_id and (patient_id, p) not in used_relationships]
    if not possible_relations:
        continue

    family_members = []

    rand_parent = random.random()
    if rand_parent <= 0.7:
        family_members.append(("FTH", "Father"))
        family_members.append(("MTH", "Mother"))
    elif rand_parent <= 0.9:
        family_members.append(random.choice([("FTH", "Father"), ("MTH", "Mother")]))

    rand_sibling = random.random()
    if rand_sibling <= 0.5:
        num_siblings = random.randint(1, 2)
        for _ in range(num_siblings):
            family_members.append(random.choice([("BRO", "Brother"), ("SIS", "Sister")]))

    chosen_family_members = random.sample(possible_relations, min(len(family_members), len(possible_relations)))

    for related_person_id, (relation_code, relation_display) in zip(chosen_family_members, family_members):
        if (related_person_id, patient_id) not in used_relationships:
            used_relationships.add((patient_id, related_person_id))
            used_relationships.add((related_person_id, patient_id))

            related_person = create_related_person(patient_id, related_person_id, relation_code, relation_display)
            family_member_history, inherited_diseases = create_family_member_history(patient_id, related_person_id, relation_code, relation_display)

            resources["RelatedPerson"].append(related_person)
            if family_member_history:
                resources["FamilyMemberHistory"].append(family_member_history)
            if inherited_diseases:
                for disease in inherited_diseases:
                    condition_for_related = create_condition_for_related_person(related_person_id, disease)
                    print(patient_id, related_person_id, disease)
                    resources["Condition"].append(condition_for_related)

print(f"\n✅ `RelatedPerson` ditambahkan: {len(resources['RelatedPerson'])}")
print(f"✅ `FamilyMemberHistory` ditambahkan: {len(resources['FamilyMemberHistory'])}")
print(f"✅ `Condition` untuk RelatedPerson ditambahkan: {len(resources['Condition'])}")
# Out:
# 7da148be-b73e-73e3-ed5c-67d7c712a253 3a644dcd-672c-9579-cdeb-65ce6783da97 Asthma
# 7da148be-b73e-73e3-ed5c-67d7c712a253 8463087b-be64-1139-b779-97d09881e034 Hypertension
# 7da148be-b73e-73e3-ed5c-67d7c712a253 8463087b-be64-1139-b779-97d09881e034 Heart Disease
# d4f1d88b-aecc-493e-2977-44a72e0de2d9 00a4d481-551d-9741-dd8f-fa88fe29ab79 Hypertension
# d4f1d88b-aecc-493e-2977-44a72e0de2d9 8c97920a-fc41-8150-f54e-9dcfc1f48fef Diabetes
# d4f1d88b-aecc-493e-2977-44a72e0de2d9 8c97920a-fc41-8150-f54e-9dcfc1f48fef Hypertension
# 9f7675c1-1f29-10ac-92e5-8aaf367f05c3 2b27a9c6-3b32-83fe-c4eb-ff271de3536b Cancer
# 9f7675c1-1f29-10ac-92e5-8aaf367f05c3 6afaf446-c5f5-8967-0c74-9174ec37994d Diabetes
# 9f7675c1-1f29-10ac-92e5-8aaf367f05c3 921dde19-cf57-df8d-5079-556b79c1c12b Asthma
# 839e461d-9a4d-a110-1fe9-97bd16378bfd 24b71f9a-cda7-8c08-2df2-4f9c9ae5db55 Heart Disease
# 839e461d-9a4d-a110-1fe9-97bd16378bfd 9f2b7772-a77d-9323-806a-e15deeb08d98 Cancer
# c498075d-c7cc-69ba-23c3-0e6a6c188592 be222f9e-05e3-7c64-349b-02949d6222c7 Cancer
# 3ada63c8-2ff1-1032-9ed5-39b5fba54c89 921dde19-cf57-df8d-5079-556b79c1c12b Heart Disease
# 3ada63c8-2ff1-1032-9ed5-39b5fba54c89 9e5d7cf6-0eab-55f0-112f-d3a24eea190f Hypertension
# 06671679-d2c8-8426-da09-7017cc0bda53 8c97920a-fc41-8150-f54e-9dcfc1f48fef Cancer
# 06671679-d2c8-8426-da09-7017cc0bda53 67ed8fab-19a2-40c5-e56c-3dfdab2c9805
# 3a644dcd-672c-9579-cdeb-65ce6783da97 7018ba97-af04-3601-0869-435454482e52 Diabetes
# 3a644dcd-672c-9579-cdeb-65ce6783da97 7018ba97-af04-3601-0869-435454482e52 Asthma
# f875dfc8-362f-4e0b-7af5-8e0aa600ec49 f4267dde-ccd3-6383-7dff-c81af29d29ff Hypertension
# f875dfc8-362f-4e0b-7af5-8e0aa600ec49 3ada63c8-2ff1-1032-9ed5-39b5fba54c89 Hypertension
# f875dfc8-362f-4e0b-7af5-8e0aa600ec49 5b1e4f94-922f-22e7-f548-e592b29f9129 Hypertension
# 209f54b3-95fe-5295-9dce-558ddc02e0c3 2f8d8644-ce85-e825-be9b-c58dfaaf159a Alzheimer
#
# ✅ `RelatedPerson` ditambahkan: 261
# ✅ `FamilyMemberHistory` ditambahkan: 193
# ✅ `Condition` untuk RelatedPerson ditambahkan: 4093

# %%
resources["Condition"]
# Out:
# [{'resourceType': 'Condition',
#   'id': 'ded1426d-62e2-77ad-0c8b-5b34075c89a9',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '314529007',
#      'display': 'Medication review due (situation)'}],
#    'text': 'Medication review due (situation)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:879a2d85-2d6a-6d2b-c3e0-8ab3527f2f47'},
#   'onsetDateTime': '2013-10-11T02:42:24+07:00',
#   'abatementDateTime': '2017-04-28T02:42:24+07:00',
#   'recordedDate': '2013-10-11T02:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': '40f951b4-d966-312a-c6b2-2b9b89ca5f30',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '314529007',
#      'display': 'Medication review due (situation)'}],
#    'text': 'Medication review due (situation)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:87154606-c4d4-19e4-3ea7-e86760ff4bf6'},
#   'onsetDateTime': '2018-05-04T02:42:24+07:00',
#   'abatementDateTime': '2018-05-04T02:42:24+07:00',
#   'recordedDate': '2018-05-04T02:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'aa6822b6-d4e2-bbe9-d4fa-574aac5c27ca',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '66383009',
#      'display': 'Gingivitis (disorder)'}],
#    'text': 'Gingivitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:87154606-c4d4-19e4-3ea7-e86760ff4bf6'},
#   'onsetDateTime': '2018-05-04T02:42:24+07:00',
#   'abatementDateTime': '2018-05-11T05:26:31+07:00',
#   'recordedDate': '2018-05-04T02:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': '35aac9a9-f1fe-8563-79d0-d279208f9098',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '314529007',
#      'display': 'Medication review due (situation)'}],
#    'text': 'Medication review due (situation)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:6d2272c2-d2b3-903f-319b-3d0c922685bc'},
#   'onsetDateTime': '2019-05-10T02:42:24+07:00',
#   'abatementDateTime': '2019-05-10T02:42:24+07:00',
#   'recordedDate': '2019-05-10T02:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': '63b4c19c-4488-56fe-e4eb-f5dd262aa4b2',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '314529007',
#      'display': 'Medication review due (situation)'}],
#    'text': 'Medication review due (situation)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:2e0b016c-54cc-88bb-4837-9dea80cfcbc2'},
#   'onsetDateTime': '2020-05-15T02:42:24+07:00',
#   'abatementDateTime': '2020-05-15T02:42:24+07:00',
#   'recordedDate': '2020-05-15T02:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'e3dc97fd-0f65-6ad7-d08b-7ef2426215bf',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '314529007',
#      'display': 'Medication review due (situation)'}],
#    'text': 'Medication review due (situation)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:b2a49e65-bf28-60ff-3347-1b6cb5b5d6a1'},
#   'onsetDateTime': '2020-05-22T02:42:24+07:00',
#   'abatementDateTime': '2020-05-22T02:42:24+07:00',
#   'recordedDate': '2020-05-22T02:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': '138c570d-aa35-9c89-8234-9124313d6309',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '66383009',
#      'display': 'Gingivitis (disorder)'}],
#    'text': 'Gingivitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:b2a49e65-bf28-60ff-3347-1b6cb5b5d6a1'},
#   'onsetDateTime': '2020-05-22T02:42:24+07:00',
#   'abatementDateTime': '2020-05-29T05:15:51+07:00',
#   'recordedDate': '2020-05-22T02:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'd0eb98e7-2714-20fb-42a9-e6eafb53dcf3',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '10509002',
#      'display': 'Acute bronchitis (disorder)'}],
#    'text': 'Acute bronchitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:ab7f1cc3-6bb2-78c9-f2d0-0ae27899b51b'},
#   'onsetDateTime': '2020-05-29T02:42:24+07:00',
#   'abatementDateTime': '2020-06-06T02:42:24+07:00',
#   'recordedDate': '2020-05-29T02:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': '2875d175-57f3-688a-ee11-f04cc6392e62',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '314529007',
#      'display': 'Medication review due (situation)'}],
#    'text': 'Medication review due (situation)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:881f0132-0d9b-7e5d-e1e0-30dcbb789b3b'},
#   'onsetDateTime': '2021-05-21T02:42:24+07:00',
#   'abatementDateTime': '2021-05-21T02:42:24+07:00',
#   'recordedDate': '2021-05-21T02:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'd492da6a-08a0-7383-e35c-30bb61520bd3',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '314529007',
#      'display': 'Medication review due (situation)'}],
#    'text': 'Medication review due (situation)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:d4aaebe1-92fb-8d2e-2c9b-54d62bebee1c'},
#   'onsetDateTime': '2022-05-27T02:42:24+07:00',
#   'abatementDateTime': '2022-05-27T02:42:24+07:00',
#   'recordedDate': '2022-05-27T02:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': '5daabbad-597d-fc85-afd2-628572e3a418',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '66383009',
#      'display': 'Gingivitis (disorder)'}],
#    'text': 'Gingivitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:d4aaebe1-92fb-8d2e-2c9b-54d62bebee1c'},
#   'onsetDateTime': '2022-05-27T04:11:53+07:00',
#   'abatementDateTime': '2022-06-10T05:12:10+07:00',
#   'recordedDate': '2022-05-27T04:11:53+07:00'},
#  {'resourceType': 'Condition',
#   'id': '1ae38334-e517-ecd3-f877-957f9760e655',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '195662009',
#      'display': 'Acute viral pharyngitis (disorder)'}],
#    'text': 'Acute viral pharyngitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:ee1743ab-609f-3292-9251-c30c3ebc59bc'},
#   'onsetDateTime': '2023-02-12T00:42:24+07:00',
#   'abatementDateTime': '2023-02-24T14:42:24+07:00',
#   'recordedDate': '2023-02-12T00:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': '4929e804-3925-20cd-c390-59cc38dd6097',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'active'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '314529007',
#      'display': 'Medication review due (situation)'}],
#    'text': 'Medication review due (situation)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:db0af997-0f21-6162-06c7-eba62458d1a6'},
#   'onsetDateTime': '2023-06-02T02:42:24+07:00',
#   'recordedDate': '2023-06-02T02:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': '6208748a-3d2f-7f93-60e3-4441aaa85220',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '66383009',
#      'display': 'Gingivitis (disorder)'}],
#    'text': 'Gingivitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:db0af997-0f21-6162-06c7-eba62458d1a6'},
#   'onsetDateTime': '2023-06-02T04:31:58+07:00',
#   'abatementDateTime': '2023-06-16T06:00:20+07:00',
#   'recordedDate': '2023-06-02T04:31:58+07:00'},
#  {'resourceType': 'Condition',
#   'id': '52157015-ac5a-4208-f001-f62cd2fffefb',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '109570002',
#      'display': 'Primary dental caries (disorder)'}],
#    'text': 'Primary dental caries (disorder)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:cf75323e-bf52-a6d2-1ffd-7869016f6456'},
#   'onsetDateTime': '2023-06-16T06:00:20+07:00',
#   'abatementDateTime': '2023-06-16T06:18:39+07:00',
#   'recordedDate': '2023-06-16T06:00:20+07:00'},
#  {'resourceType': 'Condition',
#   'id': '5931027a-a344-918b-5c14-292c3a3c4446',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '195662009',
#      'display': 'Acute viral pharyngitis (disorder)'}],
#    'text': 'Acute viral pharyngitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:e42a8b82-cdb1-a1db-0eb4-b20379daa2ec'},
#   'onsetDateTime': '2023-11-25T06:42:24+07:00',
#   'abatementDateTime': '2023-12-04T01:42:24+07:00',
#   'recordedDate': '2023-11-25T06:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': '7b4782ef-044b-8fc1-6c01-0d49e95ca734',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '66383009',
#      'display': 'Gingivitis (disorder)'}],
#    'text': 'Gingivitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:97e2a662-17a3-fcc4-3122-75f12db87af1'},
#   'onsetDateTime': '2024-06-07T03:33:33+07:00',
#   'abatementDateTime': '2024-06-21T04:57:18+07:00',
#   'recordedDate': '2024-06-07T03:33:33+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'f687b09d-3abc-2c1c-f65a-1f096d2b4378',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '444814009',
#      'display': 'Viral sinusitis (disorder)'}],
#    'text': 'Viral sinusitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:e431b8e1-e8b5-32c3-6685-3a2d9980a922'},
#   'onsetDateTime': '2024-06-14T02:42:24+07:00',
#   'abatementDateTime': '2024-07-03T02:42:24+07:00',
#   'recordedDate': '2024-06-14T02:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': '4bd9bba5-a3e0-3439-0454-ac069752cd85',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '195662009',
#      'display': 'Acute viral pharyngitis (disorder)'}],
#    'text': 'Acute viral pharyngitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:7da148be-b73e-73e3-ed5c-67d7c712a253'},
#   'encounter': {'reference': 'urn:uuid:99cf6c36-1d4b-cfb9-058e-18ca1197856f'},
#   'onsetDateTime': '2024-12-29T23:42:24+07:00',
#   'abatementDateTime': '2025-01-09T02:42:24+07:00',
#   'recordedDate': '2024-12-29T23:42:24+07:00'},
#  {'resourceType': 'Condition',
#   'id': '6e4628f0-3ef6-face-d3ed-e7a2750b280d',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '314529007',
#      'display': 'Medication review due (situation)'}],
#    'text': 'Medication review due (situation)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:d929685d-f564-04da-02ee-c7acc66cab33'},
#   'onsetDateTime': '2012-12-06T00:52:42+07:00',
#   'abatementDateTime': '2018-01-04T00:52:42+07:00',
#   'recordedDate': '2012-12-06T00:52:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': '72b698dd-f4aa-082e-2d2f-7a92c14e2592',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '66383009',
#      'display': 'Gingivitis (disorder)'}],
#    'text': 'Gingivitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:6a07d08e-b577-e89c-d740-b48f0fee09db'},
#   'onsetDateTime': '2015-12-24T01:14:09+07:00',
#   'abatementDateTime': '2016-01-07T06:18:40+07:00',
#   'recordedDate': '2015-12-24T01:14:09+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'c3933c39-e1a3-cbd2-7936-d48a1c76ea91',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '427898007',
#      'display': 'Infection of tooth (disorder)'}],
#    'text': 'Infection of tooth (disorder)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:63acfffc-b711-65e3-2731-f1b3825848d0'},
#   'onsetDateTime': '2016-01-07T02:48:38+07:00',
#   'abatementDateTime': '2016-01-07T04:18:18+07:00',
#   'recordedDate': '2016-01-07T02:48:38+07:00'},
#  {'resourceType': 'Condition',
#   'id': '0ec995a5-f2aa-d2bb-dde4-f0e25229eea2',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '61804006',
#      'display': 'Alveolitis of jaw (disorder)'}],
#    'text': 'Alveolitis of jaw (disorder)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:e8c8a1af-7e23-7b87-f658-49403def18cf'},
#   'onsetDateTime': '2016-01-12T07:09:22+07:00',
#   'abatementDateTime': '2016-01-12T08:22:43+07:00',
#   'recordedDate': '2016-01-12T07:09:22+07:00'},
#  {'resourceType': 'Condition',
#   'id': '29f59210-d001-3e11-184c-584df70b75ec',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '10509002',
#      'display': 'Acute bronchitis (disorder)'}],
#    'text': 'Acute bronchitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:587dbdeb-fd67-accf-2b02-d7b62ab32828'},
#   'onsetDateTime': '2016-08-18T00:52:42+07:00',
#   'abatementDateTime': '2016-08-31T01:17:02+07:00',
#   'recordedDate': '2016-08-18T00:52:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': '81112bce-0c16-ee06-0425-b2a76e90b2f6',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '18718003',
#      'display': 'Gingival disease (disorder)'}],
#    'text': 'Gingival disease (disorder)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:f9a21363-a01c-5346-774e-df7d1920c84b'},
#   'onsetDateTime': '2016-08-25T02:58:04+07:00',
#   'abatementDateTime': '2016-08-25T04:34:51+07:00',
#   'recordedDate': '2016-08-25T02:58:04+07:00'},
#  {'resourceType': 'Condition',
#   'id': '6f9af2ee-9efa-b3d9-242e-5af42dc1bc7e',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '195662009',
#      'display': 'Acute viral pharyngitis (disorder)'}],
#    'text': 'Acute viral pharyngitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:130a7bb2-bca8-04a6-0e86-e66d0f222638'},
#   'onsetDateTime': '2017-10-13T21:52:42+07:00',
#   'abatementDateTime': '2017-10-21T05:52:42+07:00',
#   'recordedDate': '2017-10-13T21:52:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'ab076771-a49b-0444-d3d8-b76eb643a93f',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '160968000',
#      'display': 'Risk activity involvement (finding)'}],
#    'text': 'Risk activity involvement (finding)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:95fa95ee-2786-fd64-0bbf-152d18596a18'},
#   'onsetDateTime': '2018-01-04T02:05:20+07:00',
#   'abatementDateTime': '2019-01-10T02:04:59+07:00',
#   'recordedDate': '2018-01-04T02:05:20+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'e91348cb-8aed-7bfc-ce81-fc1a3c1ef358',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '66383009',
#      'display': 'Gingivitis (disorder)'}],
#    'text': 'Gingivitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:95fa95ee-2786-fd64-0bbf-152d18596a18'},
#   'onsetDateTime': '2018-01-04T02:17:58+07:00',
#   'abatementDateTime': '2018-01-18T03:47:00+07:00',
#   'recordedDate': '2018-01-04T02:17:58+07:00'},
#  {'resourceType': 'Condition',
#   'id': '73419cd7-cf58-8880-e955-5bf6c9f2cb3d',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '307426000',
#      'display': 'Acute infective cystitis (disorder)'}],
#    'text': 'Acute infective cystitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:55690dd2-509a-ddc3-4c86-8aa03ebec852'},
#   'onsetDateTime': '2018-10-26T00:52:42+07:00',
#   'abatementDateTime': '2018-10-27T20:19:56+07:00',
#   'recordedDate': '2018-10-26T00:52:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': '1d09bdd4-58ba-7ca8-8349-c923c20aba8f',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '314529007',
#      'display': 'Medication review due (situation)'}],
#    'text': 'Medication review due (situation)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:11469237-daaf-1687-5f18-bae5cc4cd799'},
#   'onsetDateTime': '2019-01-10T00:52:42+07:00',
#   'abatementDateTime': '2023-02-02T00:52:42+07:00',
#   'recordedDate': '2019-01-10T00:52:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': '48c8cd0a-f9ba-e25a-7188-dee378570e50',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'active'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '59621000',
#      'display': 'Essential hypertension (disorder)'}],
#    'text': 'Essential hypertension (disorder)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:96ae5dc3-3727-6304-43b0-b08e5ce1b42e'},
#   'onsetDateTime': '2021-01-21T00:52:42+07:00',
#   'recordedDate': '2021-01-21T00:52:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'e79f9292-3c86-9e05-2532-8e746f90654a',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'active'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '105531004',
#      'display': 'Housing unsatisfactory (finding)'}],
#    'text': 'Housing unsatisfactory (finding)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:96ae5dc3-3727-6304-43b0-b08e5ce1b42e'},
#   'onsetDateTime': '2021-01-21T01:38:15+07:00',
#   'recordedDate': '2021-01-21T01:38:15+07:00'},
#  {'resourceType': 'Condition',
#   'id': '42200e2a-b92e-74f0-5243-4eba1b628f65',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'active'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '224299000',
#      'display': 'Received higher education (finding)'}],
#    'text': 'Received higher education (finding)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:96ae5dc3-3727-6304-43b0-b08e5ce1b42e'},
#   'onsetDateTime': '2021-01-21T01:38:15+07:00',
#   'recordedDate': '2021-01-21T01:38:15+07:00'},
#  {'resourceType': 'Condition',
#   'id': '2254f23c-cfa5-3add-55c8-2f5cc76e2f57',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'active'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '73438004',
#      'display': 'Unemployed (finding)'}],
#    'text': 'Unemployed (finding)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:96ae5dc3-3727-6304-43b0-b08e5ce1b42e'},
#   'onsetDateTime': '2021-01-21T01:38:15+07:00',
#   'recordedDate': '2021-01-21T01:38:15+07:00'},
#  {'resourceType': 'Condition',
#   'id': '9630896a-e12d-7667-61a9-abc624682b41',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '422650009',
#      'display': 'Social isolation (finding)'}],
#    'text': 'Social isolation (finding)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:96ae5dc3-3727-6304-43b0-b08e5ce1b42e'},
#   'onsetDateTime': '2021-01-21T01:38:15+07:00',
#   'abatementDateTime': '2022-01-27T01:24:24+07:00',
#   'recordedDate': '2021-01-21T01:38:15+07:00'},
#  {'resourceType': 'Condition',
#   'id': '2e8d33f1-160d-99a6-d88e-69adbc5fd2bd',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '66383009',
#      'display': 'Gingivitis (disorder)'}],
#    'text': 'Gingivitis (disorder)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:96ae5dc3-3727-6304-43b0-b08e5ce1b42e'},
#   'onsetDateTime': '2021-01-21T02:16:19+07:00',
#   'abatementDateTime': '2021-02-04T03:42:59+07:00',
#   'recordedDate': '2021-01-21T02:16:19+07:00'},
#  {'resourceType': 'Condition',
#   'id': '90bda67f-ed8c-311f-de14-dc3d172f1623',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '840544004',
#      'display': 'Suspected disease caused by Severe acute respiratory coronavirus 2 (situation)'}],
#    'text': 'Suspected disease caused by Severe acute respiratory coronavirus 2 (situation)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:b382b3a7-8458-c130-7261-666b87623f56'},
#   'onsetDateTime': '2021-05-12T00:52:42+07:00',
#   'abatementDateTime': '2021-05-12T02:02:52+07:00',
#   'recordedDate': '2021-05-12T00:52:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': '7d820ddb-2ca7-16d1-8e04-1654101372a9',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '49727002',
#      'display': 'Cough (finding)'}],
#    'text': 'Cough (finding)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:4f5c2511-3538-5f93-49f4-146d463ed6d8'},
#   'onsetDateTime': '2021-05-12T00:52:42+07:00',
#   'abatementDateTime': '2021-06-12T12:02:52+07:00',
#   'recordedDate': '2021-05-12T00:52:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'fd16dcba-4f03-0a25-8a18-794aac8f1b3d',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '267102003',
#      'display': 'Sore throat (finding)'}],
#    'text': 'Sore throat (finding)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:4f5c2511-3538-5f93-49f4-146d463ed6d8'},
#   'onsetDateTime': '2021-05-12T00:52:42+07:00',
#   'abatementDateTime': '2021-06-12T12:02:52+07:00',
#   'recordedDate': '2021-05-12T00:52:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'deb7797d-4495-2810-9473-1a3abab27955',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '248595008',
#      'display': 'Sputum finding (finding)'}],
#    'text': 'Sputum finding (finding)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:4f5c2511-3538-5f93-49f4-146d463ed6d8'},
#   'onsetDateTime': '2021-05-12T00:52:42+07:00',
#   'abatementDateTime': '2021-06-12T12:02:52+07:00',
#   'recordedDate': '2021-05-12T00:52:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'd69d58ef-430d-b7db-f417-8e5ba98c4b7e',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '386661006',
#      'display': 'Fever (finding)'}],
#    'text': 'Fever (finding)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:4f5c2511-3538-5f93-49f4-146d463ed6d8'},
#   'onsetDateTime': '2021-05-12T00:52:42+07:00',
#   'abatementDateTime': '2021-06-12T12:02:52+07:00',
#   'recordedDate': '2021-05-12T00:52:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': '380641eb-0da3-73fb-5b67-4ad135b49a14',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '840539006',
#      'display': 'Disease caused by severe acute respiratory syndrome coronavirus 2 (disorder)'}],
#    'text': 'Disease caused by severe acute respiratory syndrome coronavirus 2 (disorder)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
#   'encounter': {'reference': 'urn:uuid:4f5c2511-3538-5f93-49f4-146d463ed6d8'},
#   'onsetDateTime': '2021-05-12T02:02:52+07:00',
#   'abatementDateTime': '2021-06-12T12:02:52+07:00',
#   'recordedDate': '2021-05-12T02:02:52+07:00'},
#  {'resourceType': 'Condition',
#   'id': '29fa568a-df5e-f492-1430-d54904f414b2',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'active'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '73595000',
#      'display': 'Stress (finding)'}],
#    'text': 'Stress (finding)'},
#   'subject': {'reference': 'urn:uuid:d4f1d88b-aecc-493e-2977-44a72e0de2d9'},
# ...
#   'encounter': {'reference': 'urn:uuid:dc4fa959-c6c6-7886-9b7b-62f8b350b1c2'},
#   'onsetDateTime': '2022-01-21T17:44:42+07:00',
#   'abatementDateTime': '2022-03-14T17:44:42+07:00',
#   'recordedDate': '2022-01-21T17:44:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': '47c4dc3c-e818-1161-6969-782a4ee2f52f',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '43878008',
#      'display': 'Streptococcal sore throat (disorder)'}],
#    'text': 'Streptococcal sore throat (disorder)'},
#   'subject': {'reference': 'urn:uuid:d7384498-866e-86f8-7a86-a7d81bed727e'},
#   'encounter': {'reference': 'urn:uuid:71818513-d249-6905-0f1b-8ca7a4fda1a4'},
#   'onsetDateTime': '2022-03-28T17:44:42+07:00',
#   'abatementDateTime': '2022-04-05T06:44:42+07:00',
#   'recordedDate': '2022-03-28T17:44:42+07:00'},
#  {'resourceType': 'Condition',
#   'id': '79277d96-7042-1517-a55b-6fdfda6c49eb',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '232353008',
#      'display': 'Perennial allergic rhinitis with seasonal variation (disorder)'}],
#    'text': 'Perennial allergic rhinitis with seasonal variation (disorder)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:9aac1117-fbe4-0270-ac7a-95e818bb8db8'},
#   'onsetDateTime': '2001-09-30T20:20:43+07:00',
#   'abatementDateTime': '2015-03-17T20:20:43+07:00',
#   'recordedDate': '2001-09-30T20:20:43+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'b802f0f2-176f-4c93-bc44-d42b81670f1f',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'active'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '224295006',
#      'display': 'Only received primary school education (finding)'}],
#    'text': 'Only received primary school education (finding)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:ba20fb2d-30d3-1c68-353b-08ac97dcac17'},
#   'onsetDateTime': '2014-05-06T20:51:40+07:00',
#   'recordedDate': '2014-05-06T20:51:40+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'fd253c7e-cbce-5e79-5e0a-6a7f435f7c0e',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '160903007',
#      'display': 'Full-time employment (finding)'}],
#    'text': 'Full-time employment (finding)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:ba20fb2d-30d3-1c68-353b-08ac97dcac17'},
#   'onsetDateTime': '2014-05-06T20:51:40+07:00',
#   'abatementDateTime': '2015-05-12T21:06:27+07:00',
#   'recordedDate': '2014-05-06T20:51:40+07:00'},
#  {'resourceType': 'Condition',
#   'id': '8b28de50-686e-70ae-f0dd-66b3a29a5ee5',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '73595000',
#      'display': 'Stress (finding)'}],
#    'text': 'Stress (finding)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:ba20fb2d-30d3-1c68-353b-08ac97dcac17'},
#   'onsetDateTime': '2014-05-06T20:51:40+07:00',
#   'abatementDateTime': '2015-05-12T21:06:27+07:00',
#   'recordedDate': '2014-05-06T20:51:40+07:00'},
#  {'resourceType': 'Condition',
#   'id': '4fe179f5-e99a-1f26-07cd-cd50fa0d109f',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '314529007',
#      'display': 'Medication review due (situation)'}],
#    'text': 'Medication review due (situation)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:7c8d2507-dd52-5dc0-7659-9c7a953dfc28'},
#   'onsetDateTime': '2015-05-12T20:20:43+07:00',
#   'abatementDateTime': '2018-05-15T20:20:43+07:00',
#   'recordedDate': '2015-05-12T20:20:43+07:00'},
#  {'resourceType': 'Condition',
#   'id': '8a4f4d5f-6262-074c-d6c1-23c3b327c2da',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '160904001',
#      'display': 'Part-time employment (finding)'}],
#    'text': 'Part-time employment (finding)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:7c8d2507-dd52-5dc0-7659-9c7a953dfc28'},
#   'onsetDateTime': '2015-05-12T21:06:27+07:00',
#   'abatementDateTime': '2018-05-15T21:19:17+07:00',
#   'recordedDate': '2015-05-12T21:06:27+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'c8e9d62a-01ee-1d1a-4603-729153339d32',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '424393004',
#      'display': 'Reports of violence in the environment (finding)'}],
#    'text': 'Reports of violence in the environment (finding)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:7c8d2507-dd52-5dc0-7659-9c7a953dfc28'},
#   'onsetDateTime': '2015-05-12T21:06:27+07:00',
#   'abatementDateTime': '2018-05-15T21:19:17+07:00',
#   'recordedDate': '2015-05-12T21:06:27+07:00'},
#  {'resourceType': 'Condition',
#   'id': '10c089e1-b817-faa4-34f2-c2c63c856758',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '72892002',
#      'display': 'Normal pregnancy (finding)'}],
#    'text': 'Normal pregnancy (finding)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:ed076c0f-e8a2-b487-38ec-3093145a9af9'},
#   'onsetDateTime': '2018-02-27T20:20:43+07:00',
#   'abatementDateTime': '2018-10-16T20:20:43+07:00',
#   'recordedDate': '2018-02-27T20:20:43+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'e5aa6ce3-394a-8e27-8eb8-e175c87f39e1',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'active'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '160903007',
#      'display': 'Full-time employment (finding)'}],
#    'text': 'Full-time employment (finding)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:33356ad8-80fc-6b3f-d905-cec70a836c0f'},
#   'onsetDateTime': '2018-05-15T21:19:17+07:00',
#   'recordedDate': '2018-05-15T21:19:17+07:00'},
#  {'resourceType': 'Condition',
#   'id': '38e329be-162d-1de8-41a1-13e20297f722',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '423315002',
#      'display': 'Limited social contact (finding)'}],
#    'text': 'Limited social contact (finding)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:33356ad8-80fc-6b3f-d905-cec70a836c0f'},
#   'onsetDateTime': '2018-05-15T21:19:17+07:00',
#   'abatementDateTime': '2022-05-24T20:51:26+07:00',
#   'recordedDate': '2018-05-15T21:19:17+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'afacd5aa-b44b-c02d-bbaa-87f44735eb23',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '73595000',
#      'display': 'Stress (finding)'}],
#    'text': 'Stress (finding)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:33356ad8-80fc-6b3f-d905-cec70a836c0f'},
#   'onsetDateTime': '2018-05-15T21:19:17+07:00',
#   'abatementDateTime': '2022-05-24T20:51:26+07:00',
#   'recordedDate': '2018-05-15T21:19:17+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'ca995ade-fa7c-80eb-2cb8-f69ef5f2a103',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'resolved'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '706893006',
#      'display': 'Victim of intimate partner abuse (finding)'}],
#    'text': 'Victim of intimate partner abuse (finding)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:33356ad8-80fc-6b3f-d905-cec70a836c0f'},
#   'onsetDateTime': '2018-05-15T21:19:17+07:00',
#   'abatementDateTime': '2021-05-18T21:01:09+07:00',
#   'recordedDate': '2018-05-15T21:19:17+07:00'},
#  {'resourceType': 'Condition',
#   'id': 'dcd23068-9b48-e8b0-4762-de8c0573f0a9',
#   'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-condition-encounter-diagnosis']},
#   'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#      'code': 'active'}]},
#   'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#      'code': 'confirmed'}]},
#   'category': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-category',
#       'code': 'encounter-diagnosis',
#       'display': 'Encounter Diagnosis'}]}],
#   'code': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '59621000',
#      'display': 'Essential hypertension (disorder)'}],
#    'text': 'Essential hypertension (disorder)'},
#   'subject': {'reference': 'urn:uuid:bedcda47-5eb2-94cc-d76a-783126dda5bf'},
#   'encounter': {'reference': 'urn:uuid:36fb7924-8b4a-054f-a640-c2375f7351cd'},
#   'onsetDateTime': '2021-05-18T20:20:43+07:00',
#   'recordedDate': '2021-05-18T20:20:43+07:00'},
#  ...]

# %%
# **Simpan Semua Resource ke File JSON Terpisah**
for resource_type, resource_list in resources.items():
    output_path = os.path.join(output_folder, f"{resource_type}.json")
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(resource_list, f, indent=4)
    print(f"✅ Data {resource_type} disimpan di {output_path}")
# Out:
# ✅ Data Patient disimpan di synthea/output/processed/Patient.json
# ✅ Data Encounter disimpan di synthea/output/processed/Encounter.json
# ✅ Data Condition disimpan di synthea/output/processed/Condition.json
# ✅ Data DiagnosticReport disimpan di synthea/output/processed/DiagnosticReport.json
# ✅ Data DocumentReference disimpan di synthea/output/processed/DocumentReference.json
# ✅ Data Claim disimpan di synthea/output/processed/Claim.json
# ✅ Data ExplanationOfBenefit disimpan di synthea/output/processed/ExplanationOfBenefit.json
# ✅ Data Observation disimpan di synthea/output/processed/Observation.json
# ✅ Data Immunization disimpan di synthea/output/processed/Immunization.json
# ✅ Data Procedure disimpan di synthea/output/processed/Procedure.json
# ✅ Data SupplyDelivery disimpan di synthea/output/processed/SupplyDelivery.json
# ✅ Data MedicationRequest disimpan di synthea/output/processed/MedicationRequest.json
# ✅ Data CareTeam disimpan di synthea/output/processed/CareTeam.json
# ✅ Data CarePlan disimpan di synthea/output/processed/CarePlan.json
# ✅ Data Medication disimpan di synthea/output/processed/Medication.json
# ✅ Data MedicationAdministration disimpan di synthea/output/processed/MedicationAdministration.json
# ✅ Data Device disimpan di synthea/output/processed/Device.json
# ✅ Data ImagingStudy disimpan di synthea/output/processed/ImagingStudy.json
# ✅ Data Provenance disimpan di synthea/output/processed/Provenance.json
# ✅ Data AllergyIntolerance disimpan di synthea/output/processed/AllergyIntolerance.json
# ✅ Data Organization disimpan di synthea/output/processed/Organization.json
# ✅ Data Location disimpan di synthea/output/processed/Location.json
# ✅ Data Practitioner disimpan di synthea/output/processed/Practitioner.json
# ✅ Data PractitionerRole disimpan di synthea/output/processed/PractitionerRole.json
# ✅ Data RelatedPerson disimpan di synthea/output/processed/RelatedPerson.json
# ✅ Data FamilyMemberHistory disimpan di synthea/output/processed/FamilyMemberHistory.json
